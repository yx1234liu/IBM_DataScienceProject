# %%
import numpy as np

# %%
loaded = np.load('npdata.npz')

# %%
arr1 = np.arange(1,8,2)

# %%
arr1
# Out:
# array([1, 3, 5, 7])

# %%
arr2 = np.linspace(1,8,num=5)
arr2
# Out:
# array([1.  , 2.75, 4.5 , 6.25, 8.  ])

# %%
np.savetxt('data.txt',arr1)

# %%
a = np.loadtxt('data.txt')

# %%
a
# Out:
# array([1., 3., 5., 7.])

# %%
a == arr1
# Out:
# array([ True,  True,  True,  True])
